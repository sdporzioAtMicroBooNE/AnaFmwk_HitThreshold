# %%
# %matplotlib inline
import os, sys, json, ROOT
import numpy as np
import pandas as pd
import root_numpy as rnp
import matplotlib.pyplot as plt
import auxFunctions as af
import histoFunctions as hf
import treeFunctions as tf
from collections import OrderedDict as OD
from ipywidgets import interact, interactive, fixed, widgets
from NotebookUtils.ProgressBar import LogProgress as LP
plt.rcParams['font.family']='serif'
plt.rcParams['font.weight']='light'
plt.rcParams['font.size']=10
figsize = (16,8)

reload(tf)
i = LP(range(4))
inDir_MC = '/Users/sdporzio/FNAL/DATA/HitThreshold/Data/MC'
inDir_Physics = '/Users/sdporzio/FNAL/DATA/HitThreshold/Data/Physics'
rootDf_track_MC = tf.ConcatenateRoot(inDir_MC,'TrackHitAna/FitTrackHits/TrackTree',nFiles=2); i.next()
rootDf_track_Physics = tf.ConcatenateRoot(inDir_Physics,'TrackHitAna/FitTrackHits/TrackTree',nFiles=2); i.next()
rootDf_others_MC = tf.ConcatenateRoot(inDir_MC,'TrackHitAna/AllHits/TrackTree',nFiles=2); i.next()
rootDf_others_Physics = tf.ConcatenateRoot(inDir_Physics,'TrackHitAna/AllHits/TrackTree',nFiles=2); i.next()

# %%
reload(tf)
tf.PlotAll(rootDf_track_MC,rootDf_others_MC,jobType='MC')
tf.PlotAll(rootDf_track_Physics,rootDf_others_Physics,jobType='Physics')

# %%
reload(tf)
tf.PlotEach(rootDf_track_MC,rootDf_others_MC,jobType='MC')
tf.PlotEach(rootDf_track_Physics,rootDf_others_Physics,jobType='Physics')

# %%
reload(hf)
hf.Plot2dHitsHisto('Data/MC',jobType='MC')
hf.Plot2dHitsHisto('Data/Physics',jobType='Physics')

# %%
reload(hf)
hf.Plot1dHitsHisto('Data/MC',jobType='MC',xlim=20)
hf.Plot1dHitsHisto('Data/Physics',jobType='Physics',xlim=20)

# %%
reload(hf)
hf.Plot1dHitsHisto('Data/MC',histoName='FitWidth',jobType='MC',xlim=20)
hf.Plot1dHitsHisto('Data/Physics',histoName='FitWidth',jobType='Physics',xlim=20)
